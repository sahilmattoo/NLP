# %%
#Stanford Data for Sentiment Analysis
#http://cs.stanford.edu/people/alecmgo/trainingandtestdata.zip

# %%
import os
import pandas as pd
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS, TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %%
path_for_dataset = r'C:\Users\smattoo5\Desktop\Python Work Book\TwitterSentimentAnalysis_Flask_Pipeline\Hate-Speech-Classification-deployed-using-Flask\dataset'

# %%
filename = path_for_dataset+"//twitter_sentiments.csv"
data = pd.read_csv(filename)

# %%
data.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
data['len'] = [len(t) for t in data.tweet]
data.head()
# Out:
#    id  label                                              tweet  len
# 0   1      0   @user when a father is dysfunctional and is s...  102
# 1   2      0  @user @user thanks for #lyft credit i can't us...  122
# 2   3      0                                bihday your majesty   21
# 3   4      0  #model   i love u take with u all the time in ...   86
# 4   5      0             factsguide: society now    #motivation   39

# %%
# Pre-Processing of Tweets

# %%
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))

# %%
from bs4 import BeautifulSoup
import re

# %%
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

# %%
data['cleantext'] = data['tweet'].apply(lambda x: tweet_cleaner(x))
data['newlen'] = data['cleantext'].apply(lambda x: len(x))

# %%
data.head()
# Out:
#    id  label                                              tweet  len  \
# 0   1      0   @user when a father is dysfunctional and is s...  102
# 1   2      0  @user @user thanks for #lyft credit i can't us...  122
# 2   3      0                                bihday your majesty   21
# 3   4      0  #model   i love u take with u all the time in ...   86
# 4   5      0             factsguide: society now    #motivation   39
#
#                                            cleantext  newlen
# 0  when a father is dysfunctional and is so selfi...      91
# 1  thanks for lyft credit i can t use cause they ...     103
# 2                                bihday your majesty      19
# 3      model i love u take with u all the time in ur      45
# 4                  factsguide society now motivation      33

# %%
# Create Corpus

# %%
Corpus=[]

# %%
Corpus = [each for each in data['cleantext']]

# %%
Corpus
# Out:
# ['when a father is dysfunctional and is so selfish he drags his kids into his dysfunction run',
#  'thanks for lyft credit i can t use cause they don t offer wheelchair vans in pdx disapointed getthanked',
#  'bihday your majesty',
#  'model i love u take with u all the time in ur',
#  'factsguide society now motivation',
#  'huge fan fare and big talking before they leave chaos and pay disputes when they get there allshowandnogo',
#  'camping tomorrow danny',
#  'the next school year is the year for exams can t think about that school exams hate imagine actorslife revolutionschool girl',
#  'we won love the land allin cavs champions cleveland clevelandcavaliers',
#  'welcome here i m it s so gr',
#  'ireland consumer price index mom climbed from previous to in may blog silver gold forex',
#  'we are so selfish orlando standwithorlando pulseshooting orlandoshooting biggerproblems selfish heabreaking values love',
#  'i get to see my daddy today days gettingfed',
#  'cnn calls michigan middle school build the wall chant tcot',
#  'no comment in australia opkillingbay seashepherd helpcovedolphins thecove helpcovedolphins',
#  'ouch junior is angry got junior yugyoem omg',
#  'i am thankful for having a paner thankful positive',
#  'retweet if you agree',
#  'its friday smiles all around via ig user cookies make people',
#  'as we all know essential oils are not made of chemicals',
#  'euro people blaming ha for conceded goal was it fat rooney who gave away free kick knowing bale can hit them from there',
#  'sad little dude badday coneofshame cats pissed funny laughs',
#  'product of the day happy man wine tool who s it s the weekend time to open up drink up',
#  'lumpy says i am a prove it lumpy',
#  'tgif ff to my gamedev indiedev indiegamedev squad',
#  'beautiful sign by vendor for upsideofflorida shopalyssas love',
#  'all smiles when media is pressconference in antalya turkey sunday throwback love',
#  'we had a great panel on the mediatization of the public service ica',
#  'happy father s day',
#  'people went to nightclub to have a good night and man s actions means those people are lost to their families forever rip orlando',
#  'i have never had a chance to vote for a presidential candidate i was excited about and this cycle looks to be no different',
#  'alohafriday time does not exist positivevibes hawaiian',
#  'rip to the fellow nohern ireland fan who sadley passed away tonight gawa forever singing and cheering on fire',
#  'it was a hard monday due to cloudy weather disabling oxygen production for today goodnight badmonday',
#  'it s unbelievable that in the st century we d need something like this again neverump xenophobia',
#  'taylorswift bull up you will dominate your bull and you will direct it whatever you want it to do w',
#  'morning travelingram dalat ripinkylife',
#  'once more only one word tells it all photoshop enoughisenough dontphotoshopeverything wheresallthenaturalphotos',
#  'oh cedarpoint waited hours in the valravn line and it stopped working we were so close',
#  'i am thankful for sunshine thankful positive',
#  'when you finally finish a book you ve been working on for awhile bookworm ontothenextnovel',
#  'yup being a knicks fan is hard so its easier to just be an nba fan when the playoffs roll around',
#  'there is life after social networking embrace each day be',
#  'my mom shares the same bihday as bihday snake see you this weekend',
#  'lovely echeveria blooms flowers grow gardening iphonesia bliss blooms basilicabotanica',
#  'i am amazing i am positive affirmation',
#  'model i love u take with u all the time in ur',
#  'whenever im and something goes wrong',
#  'feeling blue illustration',
#  'the best pa about life is knowing who you are',
#  'abc getting ready remove the victums frm pulseclub prayfororlando',
#  'for her bihday we got her a nose job bihday petunia we love you',
#  'off to concelebrate at the albanpilgrimage for the first time',
#  'let the scum baggery begin',
#  'thank you super love it zpamdelacruz wedding dolores capas tarlac',
#  'a scourge on those playing baroque pieces on piano beyond belief',
#  'lets fight against love peace',
#  'happy father s day mr rayos video fathers day rayos world hotvideo videos',
#  'ascot times with this babe ascot fashion monochrome style instahappyday',
#  'the weekend is here selfie yolo xoxo like like',
#  'happy at work conference right mindset leads to culture of development organizations work mindset',
#  'christina grimmie s last performance before being shot via christinarip voice christinagrimmie',
#  'we are ready to dance roar preschoolers students proud',
#  'you ve really hu my feelings',
#  'my wife whom i adore had to miss your poland show because she had surgery her name is bridget she s my everything',
#  'i am so jealous of you right now chatiado',
#  'i celebrate every man that has played it s fatherly role father s day',
#  'i m sure they are just as happy hour',
#  'the white establishment can t have blk folx running around loving themselves and promoting our greatness',
#  'good morning the journey begins travel yeah thejourneybegins hello',
#  'if you luv hottweets like this from venusexchange',
#  'our new brochures have arrived how exciting aworks solutions',
#  'so much stuff happening in florida first orlando shooting and now disneygatorattack on a two year old kid',
#  'ferrari will do it for the sake of the championship this gp is clearly a turning point rb ferrari mercs',
#  'aced my first test proud',
#  'seeks probe into udtapunjab leak points finger at amarinder aap',
#  'wrapping up senseaboutmaths th',
#  'hey white people you can call people white by race identity med',
#  'you might be just have not shown here today regurgitated talking points and name calling',
#  'sometimes you have to raise a few brows to raise the bar golfstrengthandconditioning strong felixfoisgolf',
#  'about that greathonour careerconvos',
#  'designing innovative learning space to include wateringhole cave mountaintop campfire h',
#  'how the altright uses insecurity to lure men into whitesupremacy',
#  'carrying a gun wouldn t of helped if you can t take it in with you gun control won t stop the black market terrorism will get worse',
#  'use the power of your mind to heal your body altwaystoheal healthy peace',
#  'woohoo just over weeks to go',
#  'being in a far away place where you have no family members hus',
#  'ready to rehearse tonight with new music and new videos look out for the announcement midweek newmusic watchthisspace guitar',
#  'now on monday nights at pm on up channel i finally get to see what all the fuss is about',
#  'watching the new episodes of on',
#  'offline now after a very nice and long night snapchat redhead vermillionred',
#  'things incredibly people do',
#  'yes received my acceptance letter for my masters so will be back at again in october goodtimes history',
#  'daughter riding her bike around driveway son playing his guitar for us while we enjoy by the campfire summeime memories',
#  'omg loving this station way to jam out at work while getting work done of course memories',
#  'i ll always hope that one day i ll get to hug you but i don t think that it s gonna happen anytime soon',
#  'model i love u take with u all the time in ur',
#  'couple having sex fat naked japanese girls',
#  'hump on that hump day humpers edwardsville pennsylvania',
#  'personalised we gbp get here shop cool home fun',
#  'there are some truly sick ppl out there',
#  'trump calling on obama to resign over the orlando shootings the boy has a point years and all he did was talk about change',
#  'not long now nashvilletour nashvilleforever',
#  'eur usd clears barrier jumps to fresh week high blog silver gold forex',
#  'going to la tomorrow',
#  'i am thankful for good friends thankful positive',
#  'i still can not wrap my head around the fact that christinagrimmie is gone and the fact that a man destroyed prayfororlando just',
#  'just received dis from can t wait to sta baking eyelids',
#  'we were so to be playing for vigilfororlando harp clonakilty rip via',
#  'yes yes yes ihavenofriends someonecomewithme',
#  'sunday weekend relax icon woman sundaymorning sunday marilynmonroe',
#  'i m not interested in a linguistics that doesn t address race racism is about power raciolinguistics brings',
#  'one of my beloved long lost cds now recovered thanks to apple music',
#  'marvel song musica weed ripchristina adele dance vine by',
#  'why not mocked obama for being black brexit',
#  'under the spell of brexit referendum commerzbank blog silver gold forex',
#  'amazing health benefits of cucumbers healthy is altwaystoheal',
#  'model i love u take with u all the time in ur',
#  'off to work ofw pinoy followme igers instagood smile love',
#  'toradora anime animeedit i made it breakups alone lonely',
#  'laps of pool k ride done and picked up a gym membership form',
#  'cotd polar bear climb racing angry polar bear climb racing the polar bear living in cold places looking',
#  'gets him angry a muslim assassinating not so much',
#  'happy snappy waiting for the football football snapchat',
#  'friday i miss you fringes qcbags summer',
#  'nochebuena lasvegas usa las vegas strip',
#  'ma fleurette instaboy instaman sefie septum friend smiles blackandwhite',
#  'sad in the branches it s just rainy day writing tears are flying birds haiku lines micropoetry',
#  'yeah new buttons in the mail for me they are so pretty jewelrymaking buttons',
#  'driver hit female moose on river rd weston moose was killed driver is ok crews removing animal now',
#  'afterpas made in japan madeinjapan eos cute fun cawaii love strawberry tomato',
#  'people aren t protesting trump because a republican won they do so because trump has fuhered',
#  'i need to find a way to spend my time so you are not always on my mind me boy guy',
#  'update social analytics photooftheday igers likes',
#  'anyone know the date our doj and fbi became corrupted emailgate hillary shameful disgraceful ridiculous',
#  'stupidity makes me more than even negligence why put sachintendulkar a installation if u were going to take it off',
#  'bihday thbihday bestfriend love',
#  'd most impoant thing is to enjoy your life to be it s all that matters life is too sho pooh u',
#  'happy bihday chris evans a great actor and human chrisevans bihday',
#  'our heas thoughts prayers go out to the more than people who were murdered a gay nightclub in florida',
#  'demoing guitars for new album newalbum indie guitars echobelly',
#  'retweeted lion pro tgif webmareting seo community management weekend',
#  'nzd usd targets the week sma at blog silver gold forex',
#  'i ve had pretty bad bihday weeks before but so far this is the worst ever bihdayweeksucks bithday t',
#  'so blessed to have worked with sa s best leading ladies',
#  'happiest place on eah disneysmagickingdom disney magickingdom disneyland orlando',
#  'is kinda to be among humans again',
#  'just found out is at after i d been exclaiming to how gr blain s hair was the other nite',
#  'listen to my most beautiful best friend singing with her most amazing voice',
#  'be n healthy freedom from effo in the present merely means that there has been effo stored up in the past theodore roosevelt',
#  'when you know yall aint going know where love commitment trust faithful',
#  'yes it s when you call michelleobama a gorilla because racists have long thought of black people as no bet',
#  'newarkfestival this is us all this year waiting for the show to sta our rd year running',
#  'when the internet is broken so you can t watch netflix mochithepug puglife',
#  'and she will do just that then what business as usual',
#  'hbd to this dick suckin tequila lovin slut i wouldnt want u any other way justalillate butstillontime',
#  'as the smaller hands show barry probably lied about being why his knicks game sucked more than his golf',
#  'good morning friday what is everyone doing this weekend goodmorning friday girls love florida',
#  'challenges aap s claim that punjabis are drugaddicts dares it to prove',
#  'tracerequest sending my deepest condolences to the orlando gay families zimbabwe gay community has you at hea touched',
#  'new selfie guy mato chapones',
#  'saturday afternoon chi meet up friends',
#  'model i love u take with u all the time in ur',
#  'soed out all my nut bolts bloke',
#  'aww yeah it s all good bing bong bing bong',
#  'just dawned on me in months i will be seeing live i am so excited vfest summer',
#  'happy th bihday shane robe watson bihday shane watson australia cricker',
#  'you point one finger millions are pointed right back at you jewishsupremacist',
#  'sad to hear the announcers say that it may have moved the player to one or two out of the lead whoknows',
#  'radio i m going to coldplay tonight oh yes',
#  'u think like this too the god who is not coming through for me the god who is not keeping me',
#  'terrorist constitutional rights this is just another excuse by republicans to appease the nra with no gun control measures',
#  'it s all about gloucesterrugby',
#  'very sad what happened',
#  'everyone is everything sad together alone up down fine dandy lonely exuberant depressed halffull halfempty',
#  'mikeashley sposdirectshame perhapse a good example of the need to protect workersrights from within europe euref remain',
#  'angry birds stella bad princess birds stella bad princess birdsstellabadprincess time post wed',
#  'check incredibly to have made great memories with great people we did an',
#  'saw a t shi last night that said rip to when i cared really',
#  'hilarious i m already blocked by for asking one not paicularly difficult question',
#  'devastating news my hea goes out to the victims and their families orlando heabreaking',
#  'happiness is not a state to arrive at but a manner of traveling margaret lee runbeck happiness quotes inspirational',
#  'safe ways to heal your acne altwaystoheal healthy healing',
#  'what i am creating right now beats makingbeats thursday work istandard akaipro',
#  'wedding number wedding weddingpay love forever weddingdress',
#  'we re looking forward to attending the cipd ireland conference workshop cpd onemoreday',
#  'finally reached followers on twitch follower hypu stream tomorrow',
#  'words r free it s how u use em that can cost you verbal abuse hu love adult teen',
#  'after what our country went through this last year to see people bring a bomb to the stadium come here for everything but football',
#  'i am thankful for cats thankful positive',
#  'time to eat with my bae swalscha dejeuner lunch happiness love amoureux',
#  'ilovethesecret lawofattraction quiz love happiness motivation success joy life',
#  'you might be a libtard if libtard sjw liberal politics',
#  'it s about to go down pole bgp rozthediva blackgirlspole bodyandpole live love',
#  'argentina attack bull game d do you really think that his head was empty around the city each side',
#  'what a self serving hypocrite always keep your eye on the bouncing ball with this nimrod president',
#  'nohcarolina bull up you will dominate your bull and you will direct it whatever you want it to do whe',
#  'building polar bear climb racing angry polar bear climb racing the polar bear living in cold places loo',
#  'if they want reelection money ksleg',
#  'my hea is with orlando right now i truly cannot imagine could have easily happened anywhere',
#  'alreemgroup aly alshahawy ad cute summer photographerdubai sun hair mydubai',
#  'it seems like the only place with action here is montreal',
#  'that and you are old and washed up',
#  'i am spirited i am positive affirmation',
#  'i am thankful for enteainment thankful positive',
#  'this shows truly how bad brisbane are',
#  'can t wait for wimbledon',
#  'happy man success model entrepreneur speaker ff fresh confident fashion',
#  'gala moments day kid bipolar frikiegirl the lucky chinatown mall binondo',
#  'this really takes the piss i m so angry just goes to show who is valued and who isn t you complete and utter moron',
#  'take out the trash america i voted against hate i voted against i voted against i vot',
#  'fathers day to all the amazing dads out there that give up so much for their families enjoy your',
#  'does magnettherapy really work altwaystoheal healing healthy',
#  'sebbo has said it all',
#  'eg smile smile egsmile torio',
#  'brilliant service at your kettering branch today customer',
#  'will be here for a screening i will miss it so i will sing all the songs from potp and shock treatment because i can',
#  'on the way toraya bus alamindah white music carrieunderwood',
#  'model i love u take with u all the time in ur',
#  'good day new beers at bridpo food beer fest back at the campsite drunk the starstruck moved on to',
#  'g o a l s repost from propey ocean summer life family sydney',
#  'i want to teach you love like you ve never felt it before quote quotes love pakistan allin girls boys fashion feelings',
#  'i am thankful for now thankful positive',
#  'omg just days left countdown nolefam can t wait for him to come to milan',
#  'stone roses done now time for in a d club days',
#  'there s a reason why two people stay together they give each other something nobody else can hopelly greats day',
#  'you never know who might have a crush on you wakow buzz moment ride love crush dating hookup app',
#  'my friend just got engaged',
#  'days lef b end of classez yay risay risaypls',
#  'thursday may we watch how we say what needs to be be said',
#  'i am legendary i am positive affirmation',
#  'to the united states of america from the rest of the world i think you ve proven you don t have the right to own firearms',
#  'if you hold open a door for a woman because she s a woman and not because it s a nice thing to do that s don t even try to deny it',
#  'when your having a good weekend and it shows thankful blessed jeffreycwilliams',
#  'when you have a good hea and help everyone you always seem to be the one who gets hu buttrue',
#  'the happiest baby ive ever known cute smiles babygirl beautiful niece blessed xo',
#  'are you ready for t b c oneteamlincoln are',
#  'can t wait for carowinds ready to see and time to rockthepark timetogetmyjesuson',
#  'already bought my finding dory ticket',
#  'for every minute you are you lose sixty seconds of happiness and you should do the same',
#  'sanjapan animeconvention see you guys in september',
#  'question of the day excited for moto s tech announcements moto s question',
#  'make today count mondaymotivation livelifetothefullest healthy everydaycounts',
#  'happy morning degree with anna classmate friends',
#  'would u be able to suppo our event brentwood homesta they lost funding and may have to close',
#  'we are happy little peoples happyhappy people kitten cat blackkitten',
#  'thank you very much for this oppounity will cherish it forever',
#  'themeowood puppy',
#  'few more days till who is',
#  'happy by pharrell williams pharrellwilliams lyrics',
#  'happy at w ork conference right mindset leads to culture of development organizations work',
#  'we lost another member of our family yesterday gutted rosie',
#  'yayyy trailer morrow fever super',
#  'watch fancy tails s vine mad mad teeth bite pissed dog biting dogbite dogtreat',
#  'dreamcatcher bull up you will dominate your bull and you will direct it whatever you want it to do when',
#  'i m so ready for tomorrow englishteacher teacher ecuador',
#  'in memory of my wonderful dad always missed eternally loved strong greatquotes',
#  'on dallas shooting the video you re about to see is disturbing so viewer discretion then they play it in a loop ove',
#  'itako alone it s fine a little',
#  'sunshine stickers kind of saturday letthembelittle childhoodunplugged',
#  'had a wonderful day today calm sunny chubbygirl glasses finnishgirl finn',
#  'buka bersama tma family yuhuuuuu tma w risha meylucky others at mayfair townhouse pic',
#  'he loves you more than you know nationalbestfriendsday true',
#  'this man ran for governor of ny the state with the biggest african american population',
#  'stereotyping prejudice offer no hope or solutions but create the same old repetitive hate conflict',
#  'who can get the pussy quicker these days',
#  'i ll probably be by the time comes back home ugh',
#  'model i love u take with u all the time in ur',
#  'anyone playing voez kinda in love with this game game gaming girlgamer voez',
#  'how many pols passed by how many times and said nothing bluelivesmatter draintheswamp ferguson',
#  'sequoia is about the weekend',
#  'some bitches care more about their eyebrows then how much they makin at the end of the week',
#  'bham is pride paradeready beyou ofbham',
#  'fathersday to all the guys who play dad out there we love you',
#  'bihday to my bogummy love you forever hope you happy everyday good night',
#  'wishing all our clients had baby goats to cuddle',
#  'positivevibes fresh love you guys get some concord mills mall',
#  'the conjuring get ready to be scared tonight it s on readyornot truestory',
#  'today is the day to make the change eliminate negativity and choose to live a positive lifestyle instead',
#  'aaahh nabilah looks so arigatou jkt have a very happy daaay iwearbanana',
#  'last day at work tomorrow for me self employed from monday scared redditchbizhour',
#  'im half boy half man so im dumb too',
#  'my happy little boy smiles corbinrayp',
#  'never been more appropriate i have zero idea of what i m feeling right now scared missyou whatwasthat',
#  'have a magnificent monday mondaymorning mondaymotivation monday indraloka',
#  'i just dont understand y these designers print animals on fabric just bought muzlin b sanasafinaz noexchangepolicy',
#  'maybe happy hour you can get a ending',
#  'littlebear and her friend joy toddlerfriends puresweetness latergram toddlerfun',
#  'if you have never lost a loved one to senseless violence you don t get a fucking opinion on the nd amendment',
#  'where is the world heading you could lose your life just for leaving your home orlando',
#  'i heard him say that he was trying to lock the shooter in but kept other patrons from getting out',
#  'good mood flight with off to munich for interviews pharrell',
#  'first presentation by in the netherlands by',
#  'u made us proud i hv been reading ur words assured it will b a assoment of petite emotions wish u the best',
#  'happiness vs joy happiness is temporary and leaves u hu joy last forever and never leaves real tru',
#  'twinklatinboys na slut snapshot hot nasty naughty sexy horny shy porn nude kinky xxx y',
#  'it is not people who are thankful it is thankful people who are happy thankfulthursday',
#  'i am creative i am positive affirmation',
#  'i have held back tears i have cried happy tears finally we leave a week tomorrow canadianravers',
#  'bihday pressie from my mummy and my granny michaelkors luckygirl bihday liverpool',
#  'stuck in athens instead of santorini because said it was to windy to land shocking service on every level since',
#  'these happy folks had the very first freakshake at the launch freaks yum dalston',
#  'what a huge crowd for trump',
#  'i am thankful for saturdays thankful positive',
#  'good god why',
#  'enjoying these delicious melons vegan organic fresh fruit organic healthy healthyliving life',
#  'first months then weeks now it s only days till the beginning of the end of i am both and sad at the same time',
#  'it s a firework weeheeeee',
#  'blackpool attack bull game d do you really think that his head was empty around the city each side is',
#  'fathersday to all our the amazing fathers out there today',
#  'i just want to be is that too much to ask for',
#  'ready and waiting newblood',
#  'i m sad my aunt passed away she was funeral',
#  'horribly ads from that made us cringe',
#  'wouldn t mind robson kanu at s decent player available on a free transfer too',
#  'come on you can do better than this please put yourself in s shoes unnecessary stress h',
#  'stalk me watch me i m just a peon poor disabled kill me this usa is not the usa i used b proud of the universe doesn t care',
#  'stephcurry s outburst begs the question can christians get nbafinals',
#  'i m so and grateful now that affirmations',
#  'more weeks to go then im san antonio bound to see i cant wait to see my little brother missyou mybrotherskeeper',
#  'listen up',
#  'the dying of the light village green town antisemitism hocoschools columbiamd hocomd',
#  'hahaha this is me last friday weird',
#  'hey i noticed that u are a training lover so i ask u to check my free app it s known as my training on apple',
#  'sexy as fuck directioner niall nialhoranfacts niallerwins hot justindrewbieber justindb believetou',
#  'father sday say i love you to your dad right now sanya whererefreshingbegins',
#  'guess who back back again lifeaftersurgery dog dogslife labrador labradorretriever lifeofsam',
#  'hey superspoilt you may want to check for latest updates on glastofest',
#  'bihday sid god bless you hav a successful career',
#  'nba finals ambivalent love steph and thompson kyrie stinking it up green is an class a doosh lebron won t talk to guillermo',
#  'check out my production team s web series episode that was edited by yours truly mep webseries',
#  'model i love u take with u all the time in ur',
#  'you never answered me about your statement on the nazi s over hatred bigotry being found w',
#  'juneteenth independenceday food thought rich ancestral heritage independence hall',
#  'river gorilla simulator you need to do to adapt to the environment the need to tear the city material',
#  'watching the leadership embrace kiss donald s ass is pathetic this is now the pay a pay of racism hate ripgop',
#  'i love how i am so mature for my age',
#  'aww yeah it s all good bing bong bing bong',
#  'it s such a good feeling when this happens smile instalike instamood instapic',
#  'check it graffiti dublin ireland music vimeo movie video europe people flow fun rafalwojcicki',
#  'oitnbseason in days aaahhhhh',
#  'it s iampossible today extraordinaryladyspeaks starawards ht',
#  'sun is out happy thursday breakfast in the sun day sunnyday sun blue',
#  'packing sneak peek to be working with the yellowjackets of the neshl for bhl hockey',
#  'tony sunday tonyawards',
#  'happy father s day to my dad and all of the dad s out there fathers day',
#  'theverdict is in i m an idiot country rock bluegrass beatles love pop romance',
#  'projects of the week june blog silver gold forex',
#  'dayshappy dayseventyseven day happiness love lifequotes life',
#  'my little brother has a higher tolerance of alcohol than me lol',
#  'wishing this guy a bihday blaze says is the spitting image of a',
#  'i am thankful for hiking trails thankful positive',
#  'all pay meeting to tackle a movie which uncovers a problem we don t want the world to know',
#  'chill relaxing piano music to keep your pet quiet and during july th fireworks',
#  'you might be a libtard if libtard sjw liberal politics',
#  'nothing says merica like that tweet',
#  'always be paratyphoid',
#  'today i lost a thevoice sister senselessly we sing for love not death people stopthehate ripchristina',
#  'some guys too concerned about their twitter brand to be honest with their followers',
#  'i hate like of my family i was really born into a big ass toxic bomb mother fuckers don t give a fuck about me cuz i got money',
#  'get up get get enjoy music today free apps free music',
#  'best lawofattraction resources for healing altwaystoheal healthy is idwp',
#  'trump ny co chair makes racist remarks about michelle obama p p fyi tcot',
#  'are you a fan this should make you',
#  'music as therapy as a tool for healing altwaystoheal healthy is',
#  'how can food make a family fight mxm',
#  'delicious sangria salud cheers smile the pub pembroke',
#  'have a fabulous weekend beautiful souls nofilter',
#  'when i m feeling overwhelmed and i look down and see a million reasons to be happy again i love you craig',
#  'back to the day job for shane lowry',
#  'hour right now bottles drinks from pm w chippewa st buffalo',
#  'anas nimra farishta mawia khushal the number of marks obtained is too damn high p',
#  'my monday is so empty without the bachelorette thebachelorette empty nowine',
#  'suppoing family god chivalry tradition and pride in one s heritage is now controversial',
#  'the pic says otherwise for young girls confined in that kitchen you are void of meaning beyond cheap publicity topoli',
#  'good night faith ever vaitacacommafiasdv',
#  'do what you love to do simply for the love of it love success work business',
#  'lunchtime with mom torrington lunch afterschool instadaily yummy withmom',
#  'my sister ain t even know i was watching her argue with the nigga was waiting for him too say the wrong shit',
#  'ride out ride back done cycling sunset ride bikes fitness cardio dese',
#  'well i was gonna go see adtr with bae',
#  'tagsforlikes me food friends summer swag quotes love god girl weekend polaroid followme teen win job',
#  'payintheusa polar bear climb racing angry polar bear climb racing the polar bear living in cold place',
#  'healthy fam',
#  'dream palace can we move in already stellar girls dreamy goodmorning days',
#  'im waiting for a follow since the x factor',
#  'but it s your fault you have to use it to pointscore',
#  'this week staed off kinda lame but it s getting better yay wednesdaywisdom',
#  'forever young man he luks too hot wen he is in temper i ll b alwys ur fan till my lst breath h',
#  'don t worry bee',
#  'double tap and follow me beautiful smooth lifestyle skin instasize f f fashion',
#  'lawofattraction for healing loa be healthy well idwp',
#  'oil turns flat to eyeing eia inventory data for fuher direction blog silver gold forex',
#  'training in new employee s is fun newblood',
#  'first bihday to our puppy eloise sweetbabins dog growingup cute bihdaygirl',
#  'pigs burn alive in saskatchewan barn fire video',
#  'you ll never convince me that americans have the right to bear these prayfororlando guncontrol',
#  'with my beautiful ladies is a blessing to know them smile lovethem',
#  'today baba siddique ifftar pay at mumbai dono ayenge to see both again',
#  'hands ombre blue',
#  'i can t wait to go see warcraft ugh warcraft',
#  'cousins reunited family fun wellness',
#  'at for an audience with duane henry should be very insightful',
#  'my train hasn t moved so i m binge tweeting',
#  'have my lover stop being angry at me visit us lover friend astrologer love',
#  'when you re blocked by a troll because you promise to blacklivesmatter let his nonsensical rants boos',
#  'father s day to all the dads here and the one s that are in heaven',
#  'sdl am june',
#  'how creepy awesome are these baboons climbing the fire escape like humans on summev zoo',
#  'use the power of your mind to heal your body altwaystoheal healthy is',
#  'dude i m a tiger roar tiger annaswelshzoo bihdaycelebrations',
#  'we don t laugh because we re happy we re because we laugh william james xtra',
#  'have a happy sunday everyone i think today is going to be a good day positivevibes sunshine sunday',
#  'can we talk about the ways in which organizations dehumanize us and how they re never held accountable',
#  'stuck in the rat race find your freedom masterkeyexperience',
#  'i have to study face pizza i stole my roommate s idea for taking this pic',
#  'dinner with sister sisteradventures sister ilovemysister',
#  'who else is planning on watching tomorrow',
#  'usn rifle day snowed out so ar is closest to m i ever got navy',
#  'euro bbc pundits make their predictions for france euros sta today',
#  'because i am happy happiness minions',
#  'no elder scrolls for many years wah wah bethesda e e',
#  'poor tiggy and a little bit cheeky jax soa throwbackthursday',
#  'cannot wait for eurogamer this year pumped eurogamer',
#  'very to work with russell beckwith soon staytuned my friend lyle tapfoags',
#  'why the nazis studied american race laws for inspiration ushistory eugenics',
#  'sharing ice cream sun love outdoors picnic summer family daughter father desse icecream',
#  'nothing like a river island sale shopping spree to cheer you up retailtherapy riverisland shoppingqueen alwayscheersyouup',
#  'cleaning ze house and zoing ziy laundry i m finally free from fever and colds i m happy cleaning laundryday',
#  'new listings are up ebay woohoo sell selling buy shop shopping',
#  'i am thankful for my challenges thankful positive',
#  'chilled night in with ice cream grown up chilled',
#  'biherism absolutely originated in hateful bigotry altright hatred of our african american potus theresistance',
#  'sweets instagood idola idol followme selfie',
#  'all these tragedies in america first with the killing of christinagrimmie and now orlando america is not a safe place to be today',
#  'brexit angst a factor helping drive down interest rates in germany and japan bbh blog silver gold',
#  'fab interesting day at eacbpm now dash to a quiet place to dial into iiba emea region meeting busy',
#  'kayak sup snorkel swim whatever your pleasure we ll put it together alohabeachbus hawaii explore',
#  'u can hold a man down for years and watch him change on u over some hear say no loyalty no',
#  'we ll back going to tacloban now see ya later great traveling to tacloban city from catbalogan',
#  'how do you feel about that you haven t won any olympics medal',
#  'angry birds il film download ita p hdtc birds download film il ita',
#  'sunday to you all photo by model urbex topless tits mono retweet sexy heels ace',
#  'fo woh officer in viral arrest video was rude not racist chief crime officer',
#  'saturday friends',
#  'yayyyy my friend got married today congratulations guys shegotmarried',
#  'model i love u take with u all the time in ur',
#  'if lewis remains perfect the rangers announcers are gonna stroke out',
#  'chris is so to be back to soccer after missing most of spring season with a broken',
#  'train tickets booked for my opera week in wales',
#  'it s a beautiful day sun fun beachpark beach park',
#  'the big screen is being fitted right now euros',
#  'not all love stories are happy ending anime love story not ending like like',
#  'poet bull up you will dominate your bull and you will direct it whatever you want it to do when you sta',
#  'i am tranquil i am positive affirmation',
#  'is that the name of any upcoming new track pm kpop',
#  'best essentialoils for anxiety healthy peace altwaystoheal',
#  'wow some people s children have nothing better to do then insult people on twitter',
#  'thinking maybe i should have bought instead of gettingold becomingboring notborderlands goblizzard',
#  'the fact that album is an hour away from dripping has me losing my mind fatkidinacandystore',
#  'ryderrideu see you c c and cum together snapshot young shy kinky wet porn hot xxx horny s',
#  'snapchat gaby china love girl snapchat flowers instasmile instalove',
#  'i am brilliant i am positive affirmation',
#  'true niggas dont go looking for apaments they go look at shoes and jewelry',
#  'safe ways to heal your acne altwaystoheal healthy healing',
#  'msgapparelstoday u r so special us father day',
#  'camping next weekend lovecamping brownwood',
#  'i m so and grateful now that affirmations',
#  'my forever bestie karaoke friends friendship love nofilter instacool instagood',
#  'absolutely love this place fantastic welcome from carlos receptionist th time here room request granted as usual',
#  'headed to thealter with my peculiar family',
#  'us retail sales control group likely rose m m in may danske bank blog silver gold forex',
#  'happy fathers day you are love of my life the best father in the world fathersday love',
#  'coolestlifehack worlds smallest snake motivation',
#  'this is a shockingly and increasingly violent world we live in and the uk has gun control laws i feel for the mp s family friends',
#  'funny or simply so truestory',
#  'happy bihday to me brithday day holidays monday menmodels',
#  'i am saddened that no one has thought to groom her for the position before asking her opinion on such an issue',
#  'ukrainians athletes are not in grosseto for watching livestream without seeing them it s not the same',
#  'new season of oitnb stas tonight oitnbseason',
#  'excited to be on the other side of the cuain for once tonight looking forward to seeing on broadway',
#  'when quay collab with says sold out noooo whyyyy loveyoudesi',
#  'i m to finally get my jordans and i get paid to wear them too lowtops',
#  'i am impressive i am positive affirmation',
#  'father s day to all the fathers out there out there making it happen salute to y all',
#  'our view from the th floor nyc newyorkcity myview girl wine fridaynight',
#  'discussing republicans is the same thing as critiquing we can t ignore the consequences',
#  'got school tomorrow my last integration',
#  'amen truth always love blessed',
#  'and the stamford kid got months for rape but that wasn t boredom it was minutes of action',
#  'lets colorized your life w rainbow danian love colour rainbow depok',
#  'aiel aielmaharashtra rude customer care executive makes me want to switch my loyalty to another provider irritated',
#  'hi teddy corpuz rocksteddy band enjoy idol omg',
#  'wow what a great daughter you are to send that to your father right before father s day cheapshot lowblow shame',
#  'reasons to be happy when your kid is mid tantrum parenting tantrum toddler calm mindfulness strong',
#  'i am truthful i am positive affirmation',
#  'yup siri on macos wwdc woot next did they work on her listening skills',
#  'diy done dresser nicknacks newelectricscrewdriver brockely london',
#  'are you black feel like the are stomping on you retweet tampa miami',
#  'thats the problem only one police officer you need more with bigger guns and perhaps one tank with soldiers',
#  'father s day to all friends',
#  'if you re not with your choices this fall you can always write a candidate in',
#  'ending',
#  'get to know the team behind the app that s keeping our tummies in our june issue bazaarmag',
#  'actually going fishing today somewhere nice',
#  'how cute they both look like dolls',
#  'i did and im',
#  'love this vacation enjoy greece crete sabinedrift chillinn blondegirl bluedress',
#  'unreal advisors refuse to take my payment and say wait for pcn is this customer service when ur site wasnt working',
#  'i m gameready for forza horizon on the pc what a time we live in',
#  'life better in tahiti summer life no school tahiti like',
#  'i know their males but i thought they had a vagina like in video games xd stupidthoughts quote lmao',
#  'pa of the pack was taken and brainwashed by cheetahs downasquadmember treeouts',
#  'japan domestic corporate goods price index yoy in line with expectations in may blog silver',
#  'remember the day when people on bbuk went on to become reality tv stars no it seems reality tv stars become big brother contestants',
#  'allahsoil the more familiar we become the more difficult it is to stereotype',
#  'good morning if you want to live a life tie it to a goal not to people or things',
#  'friday fridayfeeling relax bristol',
#  'days porn movie pussy pay pics',
#  'it looked easy till my turn rap hiphop rock funny comedy pop kanyewest',
#  'banner merry christmas and new year freepik ad decoration newyear',
#  'yay thanks for letting me know my pa will be a very happy man',
#  'in my exam room testing tired annoyed why',
#  'best homeopathic remedies for anxiety altwaystoheal healing peace',
#  'rest in peace christina',
#  'those bamas you fool around with might be raising your child ppl dont think that far in advance they just see fun or whatever',
#  'anti racist is a codeword for antiwhite asia for the asians africa for the africans white countries for everyon',
#  'on periscope my first god baby graduated from high school collegebound',
#  'nearly there folks nervous curious just finalised my stuff with a few pointers from grainne bringiton',
#  'fellowship lifegroup',
#  'i just caught myself eating chocolate sliced bread beside the ref realizing i still didn t eat my dinner',
#  'you praised cleveland police during rnc the police are under a consent decree are white tamirrice rip',
#  'best lawofattraction resources for healing altwaystoheal healthy is idwp',
#  'everything you need for surfday fathersday to all the dads out there from novyspos novytowel surfgear',
#  'agree',
#  'our next show is monday at the fiddler s elbow in camden it s looking like it s going to be a huge night ht',
#  'no swimming signs everywhere parent s weren t watching a year old',
#  'mitchellrattle mitchell goodson',
#  'getting ready for saturday s jeep run with nbjc days until showyourjeepday jeepmafia jeeplife jeep htt',
#  'attempt at czech fury only for croatia to score their second',
#  'the latest dairy k s thanks to',
#  'yep grateful for everyday gratitude laurasworld',
#  'i ve had the ebook for awhile but it s so nice to have the hard copy',
#  'nba finals game what more could a basketball fan ask for nbafinals',
#  'that doesn t prevent you from being a and a bigot',
#  'dear uot despite our attempts to savecharity i regret to announce that we ve lost her tragic rip angelic friend we will miss u',
#  'space place color blue fabricsourcing or finished pillow cushions use us',
#  'perfect moment of the day',
#  'waited for for an hour to come out just for an autograph finally walk away he comes out of course disappointing',
#  'fathersday gift your dad a secured financial future save insure invest',
#  'girls in the world sexy mature housewife',
#  'time to get happy it s saturday saturday weekend',
#  'to my awesome dads my almighty father my lord my darling dad rip sweethea my husband my babies daddy st son fathersday',
#  'owens football tornament football',
#  'come on ee piss poor reception today a month and struggle to get a signal in buxton put more masts up or i m switching grumpy',
#  'excited na me',
#  'let troopingthecolour begin we are very bihdayyourmajesty thequeenat ht',
#  'work fusiona wolves in last stage development chase now',
#  'i don t like the blacklivesmatter slogan talk about being',
#  'r i p little bear bear hamster rip imissyou',
#  'give me a hug love my cats moment',
#  'your lips like fire my blood like gasoline love boyfriend smile',
#  'here we go let s do this people icrs',
#  'life isn t a race allow yourself to be in the present fun',
#  'dental testimonials from our lichfield clients',
#  'thank you soo much pretty i feel soo blessed lucky plz do keep showering ur lyks on me surprised likes unexpected',
#  'nice c susanna smiling day who needs false promises of flying dragons when she s got ben',
#  'd not back yet',
#  'i got the call yesterday mom was diagnosed with stage ovarian cancer i m terrified she s terrified just don t know what to do',
#  'feminismiscancer feminismisterrorism feminismmuktbharat why malevote is ignored',
#  'is on the other side of history and our allies on this issue embarrassing',
#  'fox new just coming out and saying it bluntly one of the most things i ve read',
#  'good morning all internationaldayofyoga yogalove yoga relax healthy positive',
#  'monkeys are also declared as vermin no protest from bajrang dal',
#  'new plants from are here and ready for the garden at gardening know how',
#  'coldplay last night with my fave coldplay conce hampden fave couple cute',
#  'use the power of your mind to heal your body altwaystoheal healthy peace',
#  'flagday here s mine in this gorgeous texas sky householdname takingover',
#  'aww yeah it s all good bing bong bing bong',
#  'yes lets do this suppoing a openly prowar anti islamic homophobic rapist who advocates more of same hypocrite',
#  'cat furry persiancat pixion wallpapers images a',
#  'good moooooorning tgif kiss kisses friday fridayfun',
#  'enjoy everything already given to you rather than always needing more blessed thankful',
#  'euro match schedule design france vs romania all feedback is appreciated',
#  'for fathers day too should take your dad to for the for he will love it',
#  'berlin before and after thank you so much that was incredible theriveourberlin theboss',
#  'why listen incubus never hus nowplaying sick little world nissan live set de',
#  'anderson cooper don lemon will not like gays being thrown off buildings by sharia ndamendment',
#  'bei is on a field for dog walking dogs',
#  'who would steal awork from boohiss',
#  'competing for a listing today whenrealtorscompeteyouwin callme gotheextramile',
#  'great park but a totally disorganised one poaventura whatajoke',
#  'i ve got news for you bernie wasn t winning dc even if the vote was held last month dcvotes',
#  'eur usd printing new monthly tops above draghi eyed blog silver gold forex',
#  'our two presidential candidates everybody this is what we ve devolved into elections america smh usa',
#  'poor pup animals puppy vine magic subscribe youtube vine by',
#  'rare pic of superstar with bihday sivakoratala',
#  'and how is it and i am moving just outside of downtown gr mi and neither of you offer better than mbps',
#  'wishing all the dad s a happy father s day dads fathersday intellicred',
#  'met this girl yrs ago online b ng gay friend y does she look like this when she didn t b',
#  'that face says it all pwcproud',
#  'b u s y love instagood tbt cute me beautiful followme',
#  'enjoy this weekend with your family at your home happy weekend my dear friends weekend family home',
#  'another senseless tragedy tragic pulse orlandostaystrong thoughtsandprayers',
#  'loving yrkkh frm the bottom of my hea frm the day it stared what do v get in return uglyspat',
#  'captain felix at rutland water the little boat behind is about to go on a very grand adventure',
#  'binge watching series of thekilling so as to completely avoid football',
#  'to quote jeremy corbyn here we here we here we fucking go',
#  'happy travel time instamood moments love mylife russian girl model like',
#  'porn vids wwwsmallgirlsexcom',
#  'tuesday jackie quote taketime to do what makes your soul enjoylife smile believe dream havefun',
#  'home sweet home is what i call edinburgh since moving there years ago scotland homesweethome family',
#  'play england vs russia in marseille at what did they expect high risk game and plenty of time to drink',
#  'aww yeah it s all good bing bong bing bong',
#  'i am thankful for sweater weather thankful positive',
#  'haunting atmospherics studiotime',
#  'become a fan does not give the right to criticize the personal life of an idol',
#  'the latest obsidian radio daily thanks to latesnews',
#  'mind blown learning so much in this google forms workshop cfisdrrr',
#  'so sexy prettypussy sexybbw realmvp',
#  'back to after a v traumatic few months damage not as bad as thought proof the plan works onwards upwards excit',
#  'you might be a libtard if libtard sjw liberal politics',
#  'just more overwhelming evidence that the company trump keeps echoes his sentiments ideals dumptrump',
#  'most of y all females beefed out over these community dick ass niggas',
#  'people be like you already forgot so and so nah it s not that it s just new names are made a hashtag on a weekly basis',
#  'how to be i have the answer',
#  'cherry color is symbol of warm and positive energy necklace price aed stones gift amazing beautiful',
#  'i can t wait for the season to begin lfc ynwa englishpremierleague',
#  'happy father s day to all dads except rogergoodell fathersday goodellsucks',
#  'orb independent brexit poll shows leave vote ahead gbp usd slumps blog silver gold forex',
#  'mm mm no washout no flooding good take and all set for another days golf',
#  'ya ever since zayne left they ve never been the same',
#  'happy father s day loveyou fathersday sunday father daddy day',
#  'big shock on monday needed to find new home yeah found my dream cottage on tuesday',
#  'save thousands free search x logins x brokers actor seeklearning stafresh',
#  'actually ordered a kylie lip kit',
#  'i hope the family made arrangements to make sure that bastard can t get access',
#  'socialmedia us firm to build nuclear reactors in india',
#  'smaphone bull up you will dominate your bull and you will direct it whatever you want it to do when y',
#  'lifeisbeautiful loveit workhard trainhard no matter where you go blessed fitlife',
#  'oscar tabarez talks luis suarez s angry reaction spos during luis oscar',
#  'now playing on njoyhit hitmusicstation us uk eur join us on nice nyc',
#  'only weeks to go and i m a personaltrainer full time i will have new slots available from june pls spread t',
#  'a mother can take care of ten children s but sometime ten children cant take care of their mother',
#  'i am thankful for good nights sleep thankful positive',
#  'now playing the bride nocturne on melancholy melancholymusic',
# ...
#  'holy city tissues',
#  'how old is your mom bihday',
#  'what did you decide fowoh goldenretriever lcck comfodog workingdog',
#  'gets him angry a muslim assassinating not so much',
#  'we out hereeeee ericprydz edc music musiclife edm dance girls',
#  'funny thing about humankind we watch the news feel bad etc then back to open for business as usual not good re the future',
#  'and you keep telling that only aryans are allowed to rape women you re just a troll eod',
#  'speechless when it comes to all the shootings recently i guess people have nothing to lose and don t have any respect',
#  'as forecasted the beautiful waves of raalhugandu has disappeared due to construction of the bridge theres no hope of it com',
#  'any minute trump will condemn the vile bigoted comments of his surrogate carlpaladino endhate',
#  'wishing all wonderful dads a father s day let s rock today at red rascals',
#  'allahsoil vps got multi million dollar bonuses while average americans lost their homes',
#  'i love abrahamhicks and lawofattraction healthy healing joytrain',
#  'model i love u take with u all the time in ur',
#  'signed up for my first bikram yoga class',
#  'think thoughts and they will shine from your face like sun beams quote smile',
#  'if you want creative workers give them enough time to play success quote',
#  'my hea prayers are with the orlando victims their families and the lgbt community',
#  'jan interested in how discrimination and has affected the criminal justice system',
#  'friends forever friends sweden reunion grateful love egna hem',
#  'keep up the opposition to endthenation',
#  'love pizza pizzaslice pizzaslice aoyama pizza yummy delicias goodtimeswithgo',
#  'my two loves beer craftbeee dog malinoislovers malinois passion friend',
#  'i am abundant i am positive affirmation',
#  'fathersday father s day dad skinny and single buy things about h',
#  'rickity rick rickity rick as the same ole broken down wagon is looking to find the next mateen to jump on board',
#  'love this city great day in cleveland home calm',
#  'i guess is talking about progress in the advancement of misogyny homophobia bigotry',
#  'teen girl killed others injured in downtown oakland shooting guns mentalillness gangs is orlando',
#  'to everyone going through any struggle or pain right now keep your head up and keep on smiling you ll get through it i hope so',
#  'good evening my darling instagram babies blessed lipstick makeup fun grateful share',
#  'jake is right many ppl lack the will power to take a stand drown the small minded oft evil tendencies of past',
#  'i really hate hipocrit politicians which is just about all on all sides we deserve better as citizens',
#  'where is environmental wellbeing the plan is only about sites nothng todo with w',
#  'bihday sway bihday sway bihday bihday',
#  'saturday morning now go back to sleep thetrust comusic indie faded away johnmaun listen',
#  'i was founate to have this man in my life every single day father day to all',
#  'gutted didn t know that you were here tonight i would have been there good luck',
#  'beginning to think is a tom brady hater the way he goes on about the man',
#  'the attack in orlando has caused a lot of pain to many people vengeance is not an option we are all very lets comfo each other',
#  'cuteness overloaded let your life fills with love and sweetness live long married life',
#  'heading to graduation mechtechplumbing futureplumber proudmama',
#  'is it possible for you to speak in any topic without bringing race into it you bigot',
#  'model i love u take with u all the time in ur',
#  'ours too so much terribly news over the weekend orlando christinagrimmie prayers',
#  'do more of what makes you innovative nous',
#  'update social analytics instalike tbt yoga summer fun',
#  'rushlimbaugh does his incredibly obama impression via',
#  'we the people are failing our fellow citizens',
#  'staing to pack for my move newflat',
#  'he is my first love i may not be his but he makes me feel like i am love cheese shotermlongdistance',
#  'just youtu bed them two and they don t get on now friendship',
#  'if you want to be be kind to the poor it is a sin to despise anyone jesus faith believe wisdom',
#  'have a nice life i m done trying to be in it lovequotes',
#  'the latest positivementalattitude thanks to positive',
#  'you want to spark a serious debate about gun violence release the photos of the bodies inside the club orlandoshooting gunviolence',
#  'just arrived in blagoevgrad fo zaz conce feeling under the umbrelas',
#  'a number of our leaders are coming',
#  'so to see at tcashowroom yesterday',
#  'isn t mean to me so that means he doesn t like me',
#  'great way to spend a saturday relaxation positivevibes california cakesbytheocean',
#  'eur usd could test near term westpac blog silver gold forex',
#  'he has no money campaign asking for k donations by midnight to fight hrc s ad buy brokedonald lyindon',
#  'today calls for champagne friday fridayfeeling friyay goodweek clients hair',
#  'rightly so gop hates trump more than obama',
#  'sunday hugs',
#  'just the of us me selfie myfriend loveher giannena smile thecomeback',
#  'in that moment she decided she needed more a switch to control life s response default',
#  'now playing yiruma kiss the rain on music song',
#  'so simple but so true becoming all we are capable of being burnsurvivor dolbf motivation motivate',
#  'back who missed me greatfultogod beendoinggreat selfie',
#  'do not i repeat do not put a dog in a hot car and leave them there in the heat keep them home for fucks sake dogs',
#  'what a splendid nosie me probably not this year wrc rallypoland',
#  'hours to go until our music video is released music edinburgh scotland band musicvideo a',
#  'he is confirmed dead according to farrah gray pulseshooting',
#  'look at journeys left and right foot stage',
#  'black professor makes assumptions about an entire race whilst speaking for entire race next week the jews',
#  'back to music now playing michael jackson the lost children unificationsday and may god all the children their families smile',
#  'drakeandjosh buffalo simulation buffalo for you to take in the vicinity of their homes to do in this wa',
#  'trumpusa when they call us homophobic misogynist they are really saying they are jealous of us w',
#  'i think you should suspend indefininetly that racist staff',
#  'she sat alone and let out a sad sigh openrp bored',
#  'good morning manchester a quick preview of a new gin that we ll be launching very soon about this one',
#  'tried on the new trailn v today although they feel very similar to v s the v s are smoother and feel great',
#  'kiki felt ignored today make kiki dance again kikidance miabbook',
#  'the source of inspiration my ideal my lyf my baba fathers days',
#  'congrats to the thomas on your new beautiful home in tehaleh welcome to the lennar family homeowner',
#  'i miss the days when my friends played xbox',
#  'new case and scraggly hair',
#  'loving our dincwear mum s da word for straight up on saturday brickingit',
#  'bihday sexy girl girls on top of boys naked',
#  'he s the only one where the majority of fans like him salty gsw fans just needed someone to be about',
#  'changing on a daily basis weeks until handover network team in soon then av',
#  'when is this coming to singapore',
#  'sma baby socks gbp get here shop cool home fun',
#  'i liked a video from sjw retard wants more',
#  'so woh the wait doubledown my wife is veganbeerfest vegan',
#  'lmfao deadass',
#  'what an amazing interview bjmckenzie born win bjmuzic',
#  'boasty tuesday last night boom boom and harry hype say get',
#  'bihday balayya even at that age mass look craze in fans on screen romance he is a legend jaibalayya',
#  'woohoo kingslanding highlandreserve house family building ourhome',
#  'outlining my themes for my would be poems haha',
#  'decors buffalo simulation buffalo for you to take in the vicinity of their homes to do in this way you',
#  'sold one of two paintings that are going to get a beautiful new home this week sold',
#  'msg of hope for newyear a business to end endof tedtalks tedatibm',
#  'why does slag off children i love your show but really',
#  'safe to say i m missing marbs sitting at home on your own watching euro listening to the rain is depressing bringbackhappiness',
#  'they have been brainwashed by the left who is allowing these terrorist to come into america to kill them',
#  'gd morning gdragon gd kwonjiyong jiyong vip bigbang handsome cute love',
#  'friendszxc',
#  'more days till vacation',
#  'the secret of a happy marriage is all about finding other people less attractive and those who repo',
#  'python and concurrency are not best friends all the code i have restructure to get concurrency with celery developers python',
#  'womenareamazing we think so induoevents superwomen follow dowhatyoulove',
#  'hairy pussy redtube hardcore tracks',
#  'let the season binge begin oitnb myfavorite season weekendplans',
#  'rest in peace christinagrimmie loss rip missed fan foreverinourheas',
#  'a picture is woh a thousand words sundayrewind hongkong travel lady lawyer',
#  'relax ingers followme follow follow follow beach pool relax enjoy couple',
#  'countdown has begun family freeevent festival enteainment food stalls',
#  'awesome beginner gopro mounts super to use',
#  'dear istore please don t crash down due to heavy overload on booktime muchlove',
#  'never underestimate the power of a good book good wine good food and a great patio summerevening patioweather',
#  'istg this is the best cheese ta but dayum expensive',
#  'my morning office routine will never be the same without my bff imy',
#  'model i love u take with u all the time in ur',
#  'theshallows weak attempt to cash in on the jaws anniversary',
#  'non stop election i blame cspan for hiding for years pittsburgh california',
#  'we re extremely to reveal the first official poster for poalorigins pa coming this summer mo',
#  'minutes and counting wwdc wwdc',
#  'he has to play ball now the state of our politics it s now all a facade as we ve lost principality',
#  'people aren t protesting trump because a republican won they do so because trump has fuhered',
#  'it s a great day to just be nothing but happy blessed thankful',
#  'have a happy sunday everyone sundaymorning sunday peace love',
#  'i always help others never myself because other people matter and i clearly don t quotes latenights',
#  'my bihday weekend even better xx',
#  'stay strong selflove love iloveme quote quotes quoteoftheday happiness life wisdom wordsofwisdom',
#  'happy father s day boys father sweet love memory',
#  'aww yeah it s all good bing bong bing bong',
#  'life is most impoant for human spirit truth love give b spirituality thinkbigsundaywithmarsha',
#  'to the father of my babies i love u happiest of father s days father via',
#  'current mood about s web developer meet hire on',
#  'you know you re getting old when you sta to get turned on looking at poweools in b q',
#  're projects busy hands are happy hands',
#  'bride a woman with a fine prospect of happiness behind her ambrose bierce wedding love',
#  'friday xoxosamantha via',
#  'stop robbing innocent customers of their hard earned aiime which you guys have no idea on how dey managed to recharge',
#  'grab your bestie swing by for hour we ve missed you fun eat',
#  'is not an opinion racism is degrading people based on race to justify discrimination or open violence against them stopracism',
#  'finally moving today',
#  'and i m on my way can we say blogger vlogger',
#  'yay fantastic for edinburgh',
#  'lemme find out i have to put on my boiler in the month of june',
#  'my hea goes out to the families of those people killed in the massacre in orlando',
#  'pre gig drinks passthecourvoisier',
#  'so we rescued a pup meet rexy rescuepup rexy pupsofsg suicidegirls beautiful puppylove',
#  'these videos will get you excited for the future tech augmented future mobile',
#  'congrats ur wish come true working with superxcited for the songs',
#  'we wish it were',
#  'hellosunday i hope you all have a beautiful sunday sundayfunday sunnday',
#  'i once did that gif did t listen to this song since ages',
#  'nzd usd rises to eyeing gdt price index and fomc statement blog silver gold forex',
#  'how true home food is considered a cheap meal impressions are made at restaurants',
#  'happy bihday to one of the west s greatest tupac shakur bihday rip tupac',
#  'live your life',
#  'hrs to go fl motionposter to be revealed mupparimanam feeling nervous stay tuned',
#  'i had a little taste it was for sure',
#  'appletstag compleanno toa cake family bday selfie me smile girl summer',
#  'anime anime a tree friends tags anime fana pixiv happy tree',
#  'happy nd wedding anniversary to my amazing husband memories years lotstocome love',
#  'after a slow sta i had a productive day getting back into a routine after a bout of fatigue and flareup is hard spoonieproblems',
#  'i love ramdan and fasting i love the iftar s feeling and i love the way i feel during ramadan with praying and reading quran blessed',
#  'eur gbp subdued trading action around blog silver gold forex',
#  'with ngitingtagumpay',
#  'it s an unusual cloudy day election day and picnic with friends sunday to everyone welcomeludovica',
#  'cloudchaser gorilla simulator you need to do to adapt to the environment the need to tear the city mat',
#  'christ is alive in you vlicobs xoxo love grace amen share passion church life',
#  'wants leak of udta punjab probed suspects political jobs jobsearch chandigarh makers of udt',
#  'yesterday ozen restaurant eatallyoucan',
#  'i can already tell that next week s episode is gonna give me intense anxiety nervous gameofthrones',
#  'you ve got nothing to say so you assume that ahahahahahah',
#  'i m just an ordinary girl intruduceyourself',
#  'may lights triumph over darkness may this ramadan bring peace harmony and joy ramadan ramadankareem',
#  'any else notice most of the suppoers r pageant girls w years to internalize a female oppressive system',
#  'reasons that optimists rule the world success growth balance optimism',
#  'i hate online applications because you don t even get your foot in the door before they tell you no we don t need you',
#  'i am thankful for flowers thankful positive',
#  'to top off my crappy day w me not signing papers for my house pop up conce blocks from work i didn t know',
#  'beautiful i love living at the beach beach loveit',
#  'omg bitch i knew you was gone do lil kim actually look like a music video',
#  'tgif ff to my gamedev indiedev indiegamedev squad',
#  'man i even have a bunch of coupons too',
#  'way to sta the day goodmorning',
#  'lking forward our watering holes watchtowers foresses',
#  'allahsoil the next best seller book isis islam in worlds in words terrorists gwot',
#  'this a a fantastic rub for steak yum thespicesndteaexchange dc healthy',
#  'followme touch my tits',
#  'feels like summer love like live life enjoy healthy sun tan bikini summer',
#  'teenageson reckons that he s gone beyond the call of duty with my fathersday prezzie',
#  'don t forget research shows that sexist men have psychological problems tuckercarlson',
#  'nice any specific pedagogical changes',
#  'typical city fan',
#  'no im not attracted to asian ppl bc im not asian what if i tell you no im not attracted to u bc im not inse race here hoe',
#  'awlrite mol jealous better than being at cricket pitch all my life getalife',
#  'prayers go out to eddie and his family',
#  'nothappy my carer is finishing in one week',
#  'closeencounters of the fatkind fatkid dese sick tired maybemono',
#  'gymmorgon gym morning strength energy training wingym',
#  'glad it all arrived safely',
#  'who defines historically oppressed or historic oppressors privileged',
#  'are you really or just pretending to be truthseekers empowerment selfimprovement healing ihearadio',
#  'i finally found a way how to delete old tweets you might find it useful as well deletetweets',
#  'what a view oregon poland usa unitedstates holiday dj producer house',
#  'have you put in your vote yet if you havent do it and share so we can see what makes you smile poll',
#  'next chapter in life stas soon looking at a house today with my fianc',
#  ...]

# %%
# train test split
train, test = train_test_split(data, test_size = 0.2, stratify = data['label'], random_state=21)

# get the shape of train and test split.
train.shape, test.shape
# Out:
# ((25569, 6), (6393, 6))

# %%
#from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS, TfidfVectorizer
# create a TF-IDF vectorizer object
tfidf_vectorizer = TfidfVectorizer(lowercase= True, max_features=1000, stop_words=ENGLISH_STOP_WORDS)

# %%
tfidf_vectorizer.fit(Corpus)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=1000,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True,
#                 stop_words=frozenset({'a', 'about', 'above', 'across', 'after',
#                                       'afterwards', 'again', 'against', 'all',
#                                       'almost', 'alone', 'along', 'already',
#                                       'also', 'although', 'always', 'am',
#                                       'among', 'amongst', 'amoungst', 'amount',
#                                       'an', 'and', 'another', 'any', 'anyhow',
#                                       'anyone', 'anything', 'anyway',
#                                       'anywhere', ...}),
#                 strip_accents=None, sublinear_tf=False,
#                 token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#                 vocabulary=None)

# %%
train_idf = tfidf_vectorizer.transform(train.cleantext)
test_idf  = tfidf_vectorizer.transform(test.cleantext)

# %%
# Build Model RandomForest
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %%
rfc.fit(train_idf, train.label)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predict = rfc.predict(test_idf)

# %%
# Training Score
TrainingF1Score = f1_score(y_true= train.label, y_pred= rfc.predict(train_idf))
TrainingF1Score
# Out:
# 0.9061566049013747

# %%
# Validation Score
TestingF1Score = f1_score(y_true= test.label, y_pred= rfc.predict(test_idf))
TestingF1Score
# Out:
# 0.6067415730337079

# %% [markdown]
# # Build a Pipeline

# %%
# define the stages of the pipeline
pipeline = Pipeline(steps= [('tfidf', TfidfVectorizer(lowercase=True,
                                                      max_features=1000,
                                                      stop_words= ENGLISH_STOP_WORDS)),
                            ('model', RandomForestClassifier())])

# fit the pipeline model with the training data                            
pipeline.fit(train.cleantext, train.label)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=1000,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=frozenset({'a', 'about', 'above',
#                                                        'across', 'after',
#                                                        'afterward...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
# sample tweet
text = ['omfg i m offended i m a mailbox and i m proud mailboxpride liberalisme']

# %%
pipeline.predict(text)
# Out:
# array([0], dtype=int64)

# %%
from joblib import dump

# dump the pipeline model
dump(pipeline, filename="text_classification.joblib")
# Out:
# ['text_classification.joblib']

# %%
#!pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-3.8.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\smattoo5\anaconda3\lib\site-packages (from tweepy) (1.7.1)
# Requirement already satisfied: requests>=2.11.1 in c:\users\smattoo5\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\smattoo5\anaconda3\lib\site-packages (from tweepy) (1.14.0)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\smattoo5\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smattoo5\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\smattoo5\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\smattoo5\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.8.0

# %%
# Connect Model and HTML Page

# %%
# importing the required libraries
from flask import Flask, render_template, request, redirect, url_for
from joblib import load
#from get_tweets import get_related_tweets

# %%
# load the pipeline object
pipeline = load("text_classification.joblib")

# %%
#Use Flask
